# %% [markdown]
# <a href="https://colab.research.google.com/github/Srikanth-c/SE-lab-w1/blob/main/SE_w1_0131.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  Implement weather modeling* using the quadratic solution in stages:
#
#  1) hard-coding variables

# %%
import matplotlib.pyplot as plt
import numpy as np
a = 4
b = -8
c = 2
x = np.linspace(-10, 10, 400)
y = a*x**2 + b*x + c
plt.figure(figsize=(6, 4))
plt.plot(x, y, label=f'{a}x^2 + {b}x + {c}')
plt.title('Plot of the quadratic function')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 2) Keyboard input

# %%
import matplotlib.pyplot as plt
import numpy as np
a=int(input("Enter the value of a: "))
b=int(input("Enter the value of b: "))
c=int(input("Enter the value of c: "))
x=np.linspace(-10, 10, 400)
y = a*x**2+b*x+c
plt.figure(figsize=(6, 4))
plt.plot(x, y, label=f'{a}x^2 + {b}x + {c}')
plt.title('Plot of the quadratic function')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Enter the value of a: 4
# Enter the value of b: -8
# Enter the value of c: 2

# %% [markdown]
# 3)  Read from a file

# %%
import matplotlib.pyplot as plt
import numpy as np
with open('C:\Users\LAB213-07\Documents\0131.txt') as file:
    a, b, c = map(float, file.readline().split())
x=np.linspace(-10, 10, 400)
y=a*x**2 + b*x + c
plt.figure(figsize=(6, 4))
plt.plot(x, y, label=f'{a}x^2 + {b}x + {c}')
plt.title('Plot of the quadratic function')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()
# Out:
#   File "<ipython-input-26-8a82c2eb8a00>", line 3
#     with open('C:\Users\LAB213-07\Documents\0131.txt') as file:
#                                                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %% [markdown]
# 4) Read multiple batches inputs from a file

# %%
import matplotlib.pyplot as plt
import numpy as np
files = 'file1.txt'
x = np.linspace(-10, 10, 400)
plt.figure(figsize=(6, 4))
with open(files, 'r') as file:
  for i, line in enumerate(file):
    a, b, c = map(float, line.split())
    y = a*x**2 + b*x + c
    plt.plot(x, y, label=f'Line {i+1}: {a}x^2 + {b}x + {c}')
plt.title('Plot of the quadratic functions')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 5) Hardcoded and user input variables

# %%
6
import matplotlib.pyplot as plt
import numpy as np
#User Input
a=int(input("Enter the value of a: "))
b=int(input("Enter the value of b: "))
c=int(input("Enter the value of c: "))
x=np.linspace(-10, 10, 400)
y1=a*x**2 + b*x + c
plt.plot(x, y1, label=f'{a}x^2 + {b}x + {c}')
#Hardcoded
a=1
b=-3
c=2
y2=a*x**2+b*x+c
plt.plot(x, y2, label=f'{a}x^2 + {b}x + {c}')
plt.title('Plot of the quadratic functions')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Enter the value of a: 5
# Enter the value of b: 7
# Enter the value of c: 8
